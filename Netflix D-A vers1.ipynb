# %% [markdown]
# # Exploring data Analysis
#
# ## Netflix shows

# %%
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import plotly.express as px

# %%
Neflix_data = pd.read_csv("netflix_titles.csv", parse_dates=["date_added"])
Neflix_data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # High level EDA

# %%
Neflix_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
Neflix_data.info()
#shape
Neflix_data.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB
# (8807, 12)

# %% [markdown]
# ## data description the difference between the method and the class

# %%
Neflix_data.describe
# Out:
# <bound method NDFrame.describe of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
Neflix_data.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# # explorind dates in matplot lib than using plotly for brtter vesulisation

# %%
Neflix_data["date_added"].hist()
# Out:
# <AxesSubplot:>

# %%
Neflix_data["release_year"].hist()
# Out:
# <AxesSubplot:>

# %%
plt.hist(Neflix_data["release_year"])
# Out:
# (array([1.000e+00, 8.000e+00, 7.000e+00, 2.100e+01, 2.700e+01, 9.900e+01,
#         1.500e+02, 2.940e+02, 1.107e+03, 7.093e+03]),
#  array([1925. , 1934.6, 1944.2, 1953.8, 1963.4, 1973. , 1982.6, 1992.2,
#         2001.8, 2011.4, 2021. ]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = 'vscode'
pio.templates.default = 'plotly'

# %%
Neflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
px.histogram(Neflix_data, x="release_year")

# %% [markdown]
# ### extracting the month from date added

# %%
Netflix_added_month = Neflix_data["date_added"].dt.month.fillna(0)               
Neflix_data["date_added_month"] = Netflix_added_month
Neflix_data["date_added_month"]
# Out:
# 0        9.0
# 1        9.0
# 2        9.0
# 3        9.0
# 4        9.0
#         ...
# 8802    11.0
# 8803     7.0
# 8804    11.0
# 8805     1.0
# 8806     3.0
# Name: date_added_month, Length: 8807, dtype: float64

# %%
Neflix_data[Neflix_data["release_year"]==1945]
# Out:
#      show_id     type                                title  \
# 1331   s1332  TV Show  Five Came Back: The Reference Films
# 7219   s7220    Movie              Know Your Enemy - Japan
# 7575   s7576    Movie             Nazi Concentration Camps
# 7930   s7931    Movie                           San Pietro
#
#                       director                         cast        country  \
# 1331                       NaN                          NaN  United States
# 7219  Frank Capra, Joris Ivens  Walter Huston, Dana Andrews  United States
# 7575            George Stevens                          NaN  United States
# 7930               John Huston                          NaN  United States
#
#      date_added  release_year rating  duration                      listed_in  \
# 1331 2021-02-09          1945  TV-MA  1 Season                       TV Shows
# 7219 2017-03-31          1945  TV-14    63 min  Classic Movies, Documentaries
# ...

# %%
plt.figure(figsize=(20,10))
test = plt.hist(Neflix_data["date_added"])
test.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10552/3506247332.py in <module>
#       1 plt.figure(figsize=(20,10))
#       2 test = plt.hist(Neflix_data["date_added"])
# ----> 3 test.show
#
# AttributeError: 'tuple' object has no attribute 'show'
